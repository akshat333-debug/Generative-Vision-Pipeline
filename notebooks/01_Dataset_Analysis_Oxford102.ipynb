# %% [markdown]
# # Phase 1: Dataset Analysis (Task 4)
# Analysis of a public dataset (Oxford-102 Flowers) to map out statistical insights such as the number of classes, dataset length, and image properties. We will also visualize images coupled with textual descriptions.

# %%
# Install dependencies
# !pip install datasets matplotlib seaborn pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load Oxford-102 Flowers Dataset
# We use the Hugging Face `datasets` hub to quickly fetch a specialized text-to-image dataset representation.

# %%
print("Loading Oxford-102 Flowers dataset...")
dataset = load_dataset('nelorth/oxford-flowers')

print("\n--- Dataset Structure ---")
print(dataset)

train_ds = dataset['train']
print(f"\nNumber of training samples: {len(train_ds)}")
print(f"Number of test samples: {len(dataset['test'])}")

# %%
### Statistical Analysis
labels = train_ds['label']
num_classes = len(set(labels))
print(f"Total distinct classes (flower species): {num_classes}")

# Examine arbitrary image resolutions on a few samples
resolutions = [img.size for img in train_ds['image'][:50]]
widths, heights = zip(*resolutions)

print(f"Average width (sample): {np.mean(widths):.2f} px")
print(f"Average height (sample): {np.mean(heights):.2f} px")

# %% [markdown]
# ### Visualization
# Let's visualize the data, mapping the visual structure directly to its corresponding classification label (which would substitute text descriptions in CGAN approaches).

# %%
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

for i in range(6):
    sample = train_ds[i]
    img = sample['image']
    label = sample['label']
    
    axes[i].imshow(img)
    axes[i].set_title(f"Flower Class ID: {label}")
    axes[i].axis('off')

plt.tight_layout()
plt.show()
